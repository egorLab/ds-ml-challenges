# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import GradientBoostingClassifier as GBC

# %%
# -*- coding: utf-8 -*-
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn.model_selection import cross_val_score   #Additional scklearn functions
from sklearn import metrics
from sklearn.grid_search import GridSearchCV   #Perforing grid search

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

target = 'open_account_flg'
IDcol = 'client_id'

# %%
all_data = pd.read_csv('all_data_added_feat.csv', delimiter='\t')
all_data.head(10)
# Out:
#         age  client_id  credit_count  credit_month  credit_sum  education  \
# 0  1.093143          1     -0.506244     -0.276958    2.089181          1
# 1 -0.805438          2      0.030756     -1.406299   -0.936193          1
# 2 -0.425721          3      1.641756      0.287712   -0.946111          3
# 3 -0.900367          4      0.030756      0.287712   -0.867189          1
# 4  0.808356          5     -0.506244     -0.276958   -0.565336          3
# 5  0.048924          6     -1.043244     -0.276958    0.043270          3
# 6 -0.235863          7      0.567756     -1.406299   -0.971431          3
# 7 -0.995296          8      0.567756     -0.276958    1.342525          1
# 8 -1.280083          9      0.567756      0.287712    0.707939          3
# 9 -0.425721         10      2.715756     -0.276958    0.011235          1
#
#    gender  job_position  living_region  marital_status  \
# 0       1            14             98               2
# ...

# %%
train = all_data[:170746]
test = all_data[train.shape[0]:]

train = train.sample(frac=0.2,random_state=42).copy()
predictors = [x for x in train.columns if x not in [target, IDcol]]

# %%
train['open_account_flg'].value_counts()
# Out:
# 0.0    28167
# 1.0     5982
# Name: open_account_flg, dtype: int64

# %%
X_train = train[predictors].copy().as_matrix()
y_train = train['open_account_flg'].as_matrix()
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=42,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
cv_score = cross_val_score(gbc, X_train_sfs, y_train, cv=5, scoring='roc_auc',n_jobs=-1)

# %%
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                                  np.std(cv_score),
                                                                                  np.min(cv_score),
                                                                                  np.max(cv_score)))
# Out:
# CV Score : Mean - 0.7632944 | Std - 0.003576337 | Min - 0.7587906 | Max - 0.768093

# %%
cv_score = cross_val_score(gbc, X_train, y_train, cv=5, scoring='roc_auc',n_jobs=-1)
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                                  np.std(cv_score),
                                                                                  np.min(cv_score),
                                                                                  np.max(cv_score)))
# Out:
# CV Score : Mean - 0.7630305 | Std - 0.003597509 | Min - 0.7584212 | Max - 0.7676057

# %%
X = train[predictors].as_matrix()
X = sfbs.transform(X)
y = train['open_account_flg'].as_matrix()

# %%
X = sfbs.transform(X)

# %%
best = sfbs.k_feature_idx_

# %%
list( predictors[i] for i in best )
# Out:
# ['age',
#  'credit_count',
#  'credit_month',
#  'credit_sum',
#  'education',
#  'gender',
#  'job_position',
#  'living_region',
#  'marital_status',
#  'monthly_income',
#  'overdue_credit_count',
#  'score_shk',
#  'tariff_id',
#  'monthly_income_group',
#  'ratio_credit_sum_to_month',
#  'ratio_credit_sum_to_month_group',
#  'ratio_monthly_income_to_credit_sum',
#  'ratio_monthly_income_to_credit_sum_group',
#  'age_group',
#  'credit_sum_group',
#  'score_shk_group',
#  'normalized_living_region',
#  'mean_income_by_normalized_living_region',
#  'diff_customer_income_mean_income_by_normalized_living_region_group',
#  'diff_customer_income_credit_sum',
#  'diff_customer_income_credit_sum_group',
#  'ratio_customer_income_to_mean_income_by_normalized_living_region',
#  'ratio_customer_income_to_mean_income_by_normalized_living_region_group',
#  'pca_num_columns',
#  'pca_all_columns',
#  'special_mean_ratio_credit_sum_to_month_group_credit_count',
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=50)

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score = cross_val_score(knn, X,
                                y,
                                cv=5, scoring='roc_auc',n_jobs=2)

# %%
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                          np.std(cv_score),
                                                                          np.min(cv_score),
                                                                          np.max(cv_score)))
# Out:
# CV Score : Mean - 0.653521 | Std - 0.007435735 | Min - 0.6399924 | Max - 0.6601664

# %%
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                          np.std(cv_score),
                                                                          np.min(cv_score),
                                                                          np.max(cv_score)))
# Out:
# CV Score : Mean - 0.6292561 | Std - 0.005993204 | Min - 0.6223527 | Max - 0.6403902

# %%
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                          np.std(cv_score),
                                                                          np.min(cv_score),
                                                                          np.max(cv_score)))
# Out:
# CV Score : Mean - 0.6659278 | Std - 0.001857892 | Min - 0.6630829 | Max - 0.6688629

# %%
print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),
                                                                          np.std(cv_score),
                                                                          np.min(cv_score),
                                                                          np.max(cv_score)))
# Out:
# CV Score : Mean - 0.66519 | Std - 0.005086223 | Min - 0.6589151 | Max - 0.6731421

# %%
gbc = GBC(random_state=42)
knn = KNeighborsClassifier(n_neighbors=50)

sfbs = SFS(gbc, 
           k_features=90, 
           forward=False, 
           floating=True, 
           scoring='roc_auc',
           verbose=2,
           cv=3,
           n_jobs=-1)
sfbs = sfbs.fit(X, y)

print('\nSequential Floating Backward Selection :')
print(sfbs.k_feature_idx_)
print('CV Score:')
print(sfbs.k_score_)
# Out:
# [2017-02-27 08:07:55] Features: 107/90 -- score: 0.76279469466
# [2017-02-27 08:44:14] Features: 106/90 -- score: 0.762812534953
# [2017-02-27 09:19:34] Features: 106/90 -- score: 0.762783940631
# [2017-02-27 09:55:20] Features: 105/90 -- score: 0.762813603234
# [2017-02-27 10:30:28] Features: 104/90 -- score: 0.762825105059
# [2017-02-27 11:05:22] Features: 104/90 -- score: 0.762825105059
# [2017-02-27 11:39:50] Features: 104/90 -- score: 0.762825105059
# [2017-02-27 12:13:12] Features: 103/90 -- score: 0.762811680328
# [2017-02-27 12:45:12] Features: 102/90 -- score: 0.762801549463
# [2017-02-27 13:19:04] Features: 101/90 -- score: 0.762812232273
# [2017-02-27 13:52:24] Features: 101/90 -- score: 0.762811074969
# [2017-02-27 14:26:14] Features: 101/90 -- score: 0.762811074969
# [2017-02-27 15:00:03] Features: 101/90 -- score: 0.762811074969
# [2017-02-27 15:31:38] Features: 100/90 -- score: 0.762795353433
# [2017-02-27 16:02:10] Features: 99/90 -- score: 0.762767969831
# ...

# %%
sfbs.k_score_
# Out:
# 0.76294663982717503

# %%
pd.DataFrame.from_dict(sfbs.get_metric_dict()).T
# Out:
#     avg_score    ci_bound                                         cv_scores  \
# 94   0.762947  0.00271217  [0.762709472544, 0.761603481229, 0.764526965709]
# 95   0.762801   0.0032303  [0.762732921312, 0.761078634775, 0.764592825233]
# 96   0.762849  0.00325145   [0.762751028674, 0.76113066006, 0.764665788825]
# 97     0.7628  0.00327757  [0.762750334292, 0.761042152979, 0.764608742619]
# 98   0.762757  0.00337648  [0.762735485186, 0.760929609576, 0.764604736566]
# 99   0.762768  0.00327444   [0.762703276514, 0.76101907811, 0.764581554868]
# 100  0.762795  0.00332952  [0.762724909204, 0.761019505422, 0.764641645674]
# 101  0.762812  0.00347818  [0.762745580441, 0.760953432243, 0.764737684136]
# 102  0.762802  0.00343442  [0.762723199955, 0.760972768129, 0.764708680307]
# 103  0.762812  0.00337117  [0.762742856325, 0.761012294525, 0.764679890134]
# 104  0.762825  0.00322672   [0.762743337051, 0.76111127076, 0.764620707367]
# ...

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.feature_selection import RFECV

gbc = GBC(random_state=42)
rfecv = RFECV(estimator=gbc, step=1, cv=3, verbose=2,n_jobs=-1,
              scoring='roc_auc')
rfecv.fit(X, y)

#f_names = np.array(train[predictors].columns)
#predictors = f_names[rfecv.support_]
# Out:
# Fitting estimator with 165 features.
# Fitting estimator with 165 features.
# Fitting estimator with 165 features.
# Fitting estimator with 164 features.
# Fitting estimator with 164 features.
# Fitting estimator with 164 features.
# Fitting estimator with 163 features.
# Fitting estimator with 163 features.
# Fitting estimator with 163 features.
# Fitting estimator with 162 features.
# Fitting estimator with 162 features.
# Fitting estimator with 162 features.
# Fitting estimator with 161 features.
# Fitting estimator with 161 features.
# Fitting estimator with 161 features.
# Fitting estimator with 160 features.
# Fitting estimator with 160 features.
# Fitting estimator with 160 features.
# Fitting estimator with 159 features.
# Fitting estimator with 159 features.
# Fitting estimator with 159 features.
# Fitting estimator with 158 features.
# Fitting estimator with 158 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# ...

# %%
f_names = np.array(train[predictors].columns)

# %%
len(f_names)
# Out:
# 165

# %%
f_names[rfecv.support_]
# Out:
# array(['age', 'credit_count', 'credit_month', 'credit_sum', 'education',
#        'gender', 'monthly_income', 'overdue_credit_count', 'score_shk',
#        'tariff_id', 'monthly_income_group', 'ratio_credit_sum_to_month',
#        'ratio_monthly_income_to_credit_sum',
#        'ratio_monthly_income_to_credit_sum_group',
#        'normalized_living_region',
#        'mean_income_by_normalized_living_region',
#        'diff_customer_income_mean_income_by_normalized_living_region',
#        'diff_customer_income_credit_sum',
#        'diff_customer_income_credit_sum_group',
#        'ratio_customer_income_to_mean_income_by_normalized_living_region',
#        'ratio_customer_income_to_mean_income_by_normalized_living_region_group',
#        'pca_num_columns', 'pca_all_columns',
#        'special_mean_ratio_credit_sum_to_month_group_score_shk',
#        'special_mean_job_position_credit_sum',
#        'special_mean_job_position_credit_month',
# ...

# %%
predictors = f_names[rfecv.support_]
