# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from datetime import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.cross_validation import KFold
from scipy.stats import skew, boxcox
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import itertools

shift = 200
COMB_FEATURE = 'cat80,cat87,cat57,cat12,cat79,cat10,cat7,cat89,cat2,cat72,' \
               'cat81,cat11,cat1,cat13,cat9,cat3,cat16,cat90,cat23,cat36,' \
               'cat73,cat103,cat40,cat28,cat111,cat6,cat76,cat50,cat5,' \
               'cat4,cat14,cat38,cat24,cat82,cat25,cat100,cat101'.split(',')

def encode(charcode):
    r = 0
    ln = len(str(charcode))
    for i in range(ln):
        r += (ord(str(charcode)[i]) - ord('A') + 1) * 26 ** (ln - i - 1)
    return r

fair_constant = 0.7
def fair_obj(preds, dtrain):
    labels = dtrain.get_label()
    x = (preds - labels)
    den = abs(x) + fair_constant
    grad = fair_constant * x / (den)
    hess = fair_constant * fair_constant / (den * den)
    return grad, hess

def xg_eval_mae(yhat, dtrain):
    y = dtrain.get_label()
    return 'mae', mean_absolute_error(np.exp(y)-shift,
                                      np.exp(yhat)-shift)
def mungeskewed(train, test, numeric_feats):
    ntrain = train.shape[0]
    test['loss'] = 0
    train_test = pd.concat((train, test)).reset_index(drop=True)
    skewed_feats = train[numeric_feats].apply(lambda x: skew(x.dropna()))
    skewed_feats = skewed_feats[skewed_feats > 0.25]
    skewed_feats = skewed_feats.index

    for feats in skewed_feats:
        train_test[feats] = train_test[feats] + 1
        train_test[feats], lam = boxcox(train_test[feats])
    return train_test, ntrain

if __name__ == "__main__":

    print('\nStarted')
    directory = 'C:\\Users\\Egor\\Desktop\\kaggle\\allstate\\'
    train = pd.read_csv(directory + 'train\\' +'train.csv')
    #train_new_c = pd.read_csv(directory + 'train\\' +'train_new_c.csv')
    #train_new_c.drop('Unnamed: 0',1,inplace=True)
    #train = pd.concat([train_old, train_new_c], axis=1)

    test = pd.read_csv(directory + 'test\\' + 'test.csv')
    #test_new_c = pd.read_csv(directory+ 'train\\' +'test_new_c.csv')
    #test_new_c.drop('Unnamed: 0',1,inplace=True)
    #test = pd.concat([test_old, test_new_c], axis=1)

    numeric_feats = [x for x in train.columns[1:-1] if 'cont' in x]
    categorical_feats = [x for x in train.columns[1:-1] if 'cat' in x]
    train_test, ntrain = mungeskewed(train, test, numeric_feats)
    
    # taken from Vladimir's script (https://www.kaggle.com/iglovikov/allstate-claims-severity/xgb-1114)
    for column in list(train.select_dtypes(include=['object']).columns):
        if train[column].nunique() != test[column].nunique():
            set_train = set(train[column].unique())
            set_test = set(test[column].unique())
            remove_train = set_train - set_test
            remove_test = set_test - set_train

            remove = remove_train.union(remove_test)


            def filter_cat(x):
                if x in remove:
                    return np.nan
                return x


            train_test[column] = train_test[column].apply(lambda x: filter_cat(x), 1)

    # taken from Ali's script (https://www.kaggle.com/aliajouz/allstate-claims-severity/singel-model-lb-1117)
    train_test["cont1"] = np.sqrt(preprocessing.minmax_scale(train_test["cont1"]))
    train_test["cont4"] = np.sqrt(preprocessing.minmax_scale(train_test["cont4"]))
    train_test["cont5"] = np.sqrt(preprocessing.minmax_scale(train_test["cont5"]))
    train_test["cont8"] = np.sqrt(preprocessing.minmax_scale(train_test["cont8"]))
    train_test["cont10"] = np.sqrt(preprocessing.minmax_scale(train_test["cont10"]))
    train_test["cont11"] = np.sqrt(preprocessing.minmax_scale(train_test["cont11"]))
    train_test["cont12"] = np.sqrt(preprocessing.minmax_scale(train_test["cont12"]))

    train_test["cont6"] = np.log(preprocessing.minmax_scale(train_test["cont6"]) + 0000.1)
    train_test["cont7"] = np.log(preprocessing.minmax_scale(train_test["cont7"]) + 0000.1)
    train_test["cont9"] = np.log(preprocessing.minmax_scale(train_test["cont9"]) + 0000.1)
    train_test["cont13"] = np.log(preprocessing.minmax_scale(train_test["cont13"]) + 0000.1)
    train_test["cont14"] = (np.maximum(train_test["cont14"] - 0.179722, 0) / 0.665122) ** 0.25

    print('')
    for comb in itertools.combinations(COMB_FEATURE, 2):
        feat = comb[0] + "_" + comb[1]
        train_test[feat] = train_test[comb[0]] + train_test[comb[1]]
        train_test[feat] = train_test[feat].apply(encode)
        print('Combining Columns:', feat)

    print('')
    for col in categorical_feats:
        print('Analyzing Column:', col)
        train_test[col] = train_test[col].apply(encode)

    print(train_test[categorical_feats])

    ss = StandardScaler()
    train_test[numeric_feats] = \
        ss.fit_transform(train_test[numeric_feats].values)

    train = train_test.iloc[:ntrain, :].copy()
    test = train_test.iloc[ntrain:, :].copy()

    print('\nMedian Loss:', train.loss.median())
    print('Mean Loss:', train.loss.mean())

    ids = pd.read_csv(directory + 'test\\' + 'test.csv')['id']
    train_y = np.log(train['loss'] + shift)
    train_x = train.drop(['loss','id'], axis=1)
    test_x = test.drop(['loss','id'], axis=1)

    n_folds = 10
    cv_sum = 0
    early_stopping = 100
    fpred = []
    xgb_rounds = []

    d_train_full = xgb.DMatrix(train_x, label=train_y)
    d_test = xgb.DMatrix(test_x)

    kf = KFold(train.shape[0], n_folds=n_folds)
    for i, (train_index, test_index) in enumerate(kf):
        print('\n Fold %d' % (i+1))
        X_train, X_val = train_x.iloc[train_index], train_x.iloc[test_index]
        y_train, y_val = train_y.iloc[train_index], train_y.iloc[test_index]

        rand_state = 2016

        params = {
            'seed': 0,
            'colsample_bytree': 0.7,
            'silent': 1,
            'subsample': 0.7,
            'learning_rate': 0.03,
            'objective': 'reg:linear',
            'max_depth': 12,
            'min_child_weight': 100,
            'booster': 'gbtree'}

        d_train = xgb.DMatrix(X_train, label=y_train)
        d_valid = xgb.DMatrix(X_val, label=y_val)
        watchlist = [(d_train, 'train'), (d_valid, 'eval')]

        clf = xgb.train(params,
                        d_train,
                        100000,
                        watchlist,
                        early_stopping_rounds=50,
                        obj=fair_obj,
                        feval=xg_eval_mae)

        xgb_rounds.append(clf.best_iteration)
        scores_val = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)
        cv_score = mean_absolute_error(np.exp(y_val), np.exp(scores_val))
        print('eval-MAE: %.6f' % cv_score)
        y_pred = np.exp(clf.predict(d_test, ntree_limit=clf.best_ntree_limit)) - shift

        if i > 0:
            fpred = pred + y_pred
        else:
            fpred = y_pred
        pred = fpred
        cv_sum = cv_sum + cv_score

    mpred = pred / n_folds
    score = cv_sum / n_folds
    print('Average eval-MAE: %.6f' % score)
    n_rounds = int(np.mean(xgb_rounds))

    print("Writing results")
    result = pd.DataFrame(mpred, columns=['loss'])
    result["id"] = ids
    result = result.set_index("id")
    print("%d-fold average prediction:" % n_folds)

    now = datetime.now()
    score = str(round((cv_sum / n_folds), 6))
    sub_file = 'C:\\Users\\Egor\\Desktop\\kaggle\\allstate\\04\\submission_5fold-average-xgb_fairobj_' + str(score) + '_' + str(
        now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
    print("Writing submission: %s" % sub_file)
    result.to_csv(sub_file, index=True, index_label='id')
# Out:
# C:\Users\Egor\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Started
#
# Combining Columns: cat80_cat87
# Combining Columns: cat80_cat57
# Combining Columns: cat80_cat12
# Combining Columns: cat80_cat79
# Combining Columns: cat80_cat10
# Combining Columns: cat80_cat7
# Combining Columns: cat80_cat89
# Combining Columns: cat80_cat2
# Combining Columns: cat80_cat72
# Combining Columns: cat80_cat81
# Combining Columns: cat80_cat11
# Combining Columns: cat80_cat1
# Combining Columns: cat80_cat13
# Combining Columns: cat80_cat9
# Combining Columns: cat80_cat3
# Combining Columns: cat80_cat16
# Combining Columns: cat80_cat90
# Combining Columns: cat80_cat23
# Combining Columns: cat80_cat36
# Combining Columns: cat80_cat73
# Combining Columns: cat80_cat103
# Combining Columns: cat80_cat40
# Combining Columns: cat80_cat28
# Combining Columns: cat80_cat111
# Combining Columns: cat80_cat6
# Combining Columns: cat80_cat76
# Combining Columns: cat80_cat50
# Combining Columns: cat80_cat5
# Combining Columns: cat80_cat4
# Combining Columns: cat80_cat14
# Combining Columns: cat80_cat38
# Combining Columns: cat80_cat24
# Combining Columns: cat80_cat82
# Combining Columns: cat80_cat25
# Combining Columns: cat80_cat100
# Combining Columns: cat80_cat101
# Combining Columns: cat80_cat114
# Combining Columns: cat87_cat57
# Combining Columns: cat87_cat12
# Combining Columns: cat87_cat79
# Combining Columns: cat87_cat10
# Combining Columns: cat87_cat7
# Combining Columns: cat87_cat89
# Combining Columns: cat87_cat2
# Combining Columns: cat87_cat72
# Combining Columns: cat87_cat81
# Combining Columns: cat87_cat11
# Combining Columns: cat87_cat1
# Combining Columns: cat87_cat13
# Combining Columns: cat87_cat9
# Combining Columns: cat87_cat3
# Combining Columns: cat87_cat16
# Combining Columns: cat87_cat90
# Combining Columns: cat87_cat23
# Combining Columns: cat87_cat36
# Combining Columns: cat87_cat73
# Combining Columns: cat87_cat103
# Combining Columns: cat87_cat40
# Combining Columns: cat87_cat28
# Combining Columns: cat87_cat111
# Combining Columns: cat87_cat6
# Combining Columns: cat87_cat76
# Combining Columns: cat87_cat50
# Combining Columns: cat87_cat5
# Combining Columns: cat87_cat4
# Combining Columns: cat87_cat14
# Combining Columns: cat87_cat38
# Combining Columns: cat87_cat24
# Combining Columns: cat87_cat82
# Combining Columns: cat87_cat25
# Combining Columns: cat87_cat100
# Combining Columns: cat87_cat101
# Combining Columns: cat87_cat114
# Combining Columns: cat57_cat12
# Combining Columns: cat57_cat79
# Combining Columns: cat57_cat10
# Combining Columns: cat57_cat7
# Combining Columns: cat57_cat89
# Combining Columns: cat57_cat2
# Combining Columns: cat57_cat72
# Combining Columns: cat57_cat81
# Combining Columns: cat57_cat11
# Combining Columns: cat57_cat1
# Combining Columns: cat57_cat13
# Combining Columns: cat57_cat9
# Combining Columns: cat57_cat3
# Combining Columns: cat57_cat16
# Combining Columns: cat57_cat90
# Combining Columns: cat57_cat23
# Combining Columns: cat57_cat36
# Combining Columns: cat57_cat73
# Combining Columns: cat57_cat103
# Combining Columns: cat57_cat40
# Combining Columns: cat57_cat28
# Combining Columns: cat57_cat111
# Combining Columns: cat57_cat6
# Combining Columns: cat57_cat76
# Combining Columns: cat57_cat50
# Combining Columns: cat57_cat5
# Combining Columns: cat57_cat4
# Combining Columns: cat57_cat14
# Combining Columns: cat57_cat38
# Combining Columns: cat57_cat24
# Combining Columns: cat57_cat82
# Combining Columns: cat57_cat25
# Combining Columns: cat57_cat100
# Combining Columns: cat57_cat101
# Combining Columns: cat57_cat114
# Combining Columns: cat12_cat79
# Combining Columns: cat12_cat10
# Combining Columns: cat12_cat7
# Combining Columns: cat12_cat89
# Combining Columns: cat12_cat2
# Combining Columns: cat12_cat72
# Combining Columns: cat12_cat81
# Combining Columns: cat12_cat11
# Combining Columns: cat12_cat1
# Combining Columns: cat12_cat13
# Combining Columns: cat12_cat9
# Combining Columns: cat12_cat3
# Combining Columns: cat12_cat16
# Combining Columns: cat12_cat90
# Combining Columns: cat12_cat23
# Combining Columns: cat12_cat36
# Combining Columns: cat12_cat73
# Combining Columns: cat12_cat103
# Combining Columns: cat12_cat40
# Combining Columns: cat12_cat28
# Combining Columns: cat12_cat111
# Combining Columns: cat12_cat6
# Combining Columns: cat12_cat76
# Combining Columns: cat12_cat50
# Combining Columns: cat12_cat5
# Combining Columns: cat12_cat4
# Combining Columns: cat12_cat14
# Combining Columns: cat12_cat38
# Combining Columns: cat12_cat24
# Combining Columns: cat12_cat82
# Combining Columns: cat12_cat25
# Combining Columns: cat12_cat100
# Combining Columns: cat12_cat101
# Combining Columns: cat12_cat114
# Combining Columns: cat79_cat10
# Combining Columns: cat79_cat7
# Combining Columns: cat79_cat89
# Combining Columns: cat79_cat2
# Combining Columns: cat79_cat72
# Combining Columns: cat79_cat81
# Combining Columns: cat79_cat11
# Combining Columns: cat79_cat1
# Combining Columns: cat79_cat13
# Combining Columns: cat79_cat9
# Combining Columns: cat79_cat3
# Combining Columns: cat79_cat16
# Combining Columns: cat79_cat90
# Combining Columns: cat79_cat23
# Combining Columns: cat79_cat36
# Combining Columns: cat79_cat73
# Combining Columns: cat79_cat103
# Combining Columns: cat79_cat40
# Combining Columns: cat79_cat28
# Combining Columns: cat79_cat111
# Combining Columns: cat79_cat6
# Combining Columns: cat79_cat76
# Combining Columns: cat79_cat50
# Combining Columns: cat79_cat5
# Combining Columns: cat79_cat4
# Combining Columns: cat79_cat14
# Combining Columns: cat79_cat38
# Combining Columns: cat79_cat24
# Combining Columns: cat79_cat82
# Combining Columns: cat79_cat25
# Combining Columns: cat79_cat100
# Combining Columns: cat79_cat101
# Combining Columns: cat79_cat114
# Combining Columns: cat10_cat7
# Combining Columns: cat10_cat89
# Combining Columns: cat10_cat2
# Combining Columns: cat10_cat72
# Combining Columns: cat10_cat81
# Combining Columns: cat10_cat11
# Combining Columns: cat10_cat1
# Combining Columns: cat10_cat13
# Combining Columns: cat10_cat9
# Combining Columns: cat10_cat3
# Combining Columns: cat10_cat16
# Combining Columns: cat10_cat90
# Combining Columns: cat10_cat23
# Combining Columns: cat10_cat36
# Combining Columns: cat10_cat73
# Combining Columns: cat10_cat103
# Combining Columns: cat10_cat40
# Combining Columns: cat10_cat28
# Combining Columns: cat10_cat111
# Combining Columns: cat10_cat6
# Combining Columns: cat10_cat76
# Combining Columns: cat10_cat50
# Combining Columns: cat10_cat5
# Combining Columns: cat10_cat4
# Combining Columns: cat10_cat14
# Combining Columns: cat10_cat38
# Combining Columns: cat10_cat24
# Combining Columns: cat10_cat82
# Combining Columns: cat10_cat25
# Combining Columns: cat10_cat100
# Combining Columns: cat10_cat101
# Combining Columns: cat10_cat114
# Combining Columns: cat7_cat89
# Combining Columns: cat7_cat2
# Combining Columns: cat7_cat72
# Combining Columns: cat7_cat81
# Combining Columns: cat7_cat11
# Combining Columns: cat7_cat1
# Combining Columns: cat7_cat13
# Combining Columns: cat7_cat9
# Combining Columns: cat7_cat3
# Combining Columns: cat7_cat16
# Combining Columns: cat7_cat90
# Combining Columns: cat7_cat23
# Combining Columns: cat7_cat36
# Combining Columns: cat7_cat73
# Combining Columns: cat7_cat103
# Combining Columns: cat7_cat40
# Combining Columns: cat7_cat28
# Combining Columns: cat7_cat111
# Combining Columns: cat7_cat6
# Combining Columns: cat7_cat76
# Combining Columns: cat7_cat50
# Combining Columns: cat7_cat5
# Combining Columns: cat7_cat4
# Combining Columns: cat7_cat14
# Combining Columns: cat7_cat38
# Combining Columns: cat7_cat24
# Combining Columns: cat7_cat82
# Combining Columns: cat7_cat25
# Combining Columns: cat7_cat100
# Combining Columns: cat7_cat101
# Combining Columns: cat7_cat114
# Combining Columns: cat89_cat2
# Combining Columns: cat89_cat72
# Combining Columns: cat89_cat81
# Combining Columns: cat89_cat11
# Combining Columns: cat89_cat1
# Combining Columns: cat89_cat13
# Combining Columns: cat89_cat9
# Combining Columns: cat89_cat3
# Combining Columns: cat89_cat16
# Combining Columns: cat89_cat90
# Combining Columns: cat89_cat23
# Combining Columns: cat89_cat36
# Combining Columns: cat89_cat73
# Combining Columns: cat89_cat103
# Combining Columns: cat89_cat40
# Combining Columns: cat89_cat28
# Combining Columns: cat89_cat111
# Combining Columns: cat89_cat6
# Combining Columns: cat89_cat76
# Combining Columns: cat89_cat50
# Combining Columns: cat89_cat5
# Combining Columns: cat89_cat4
# Combining Columns: cat89_cat14
# Combining Columns: cat89_cat38
# Combining Columns: cat89_cat24
# Combining Columns: cat89_cat82
# Combining Columns: cat89_cat25
# Combining Columns: cat89_cat100
# Combining Columns: cat89_cat101
# Combining Columns: cat89_cat114
# Combining Columns: cat2_cat72
# Combining Columns: cat2_cat81
# Combining Columns: cat2_cat11
# Combining Columns: cat2_cat1
# Combining Columns: cat2_cat13
# Combining Columns: cat2_cat9
# Combining Columns: cat2_cat3
# Combining Columns: cat2_cat16
# Combining Columns: cat2_cat90
# Combining Columns: cat2_cat23
# Combining Columns: cat2_cat36
# Combining Columns: cat2_cat73
# Combining Columns: cat2_cat103
# Combining Columns: cat2_cat40
# Combining Columns: cat2_cat28
# Combining Columns: cat2_cat111
# Combining Columns: cat2_cat6
# Combining Columns: cat2_cat76
# Combining Columns: cat2_cat50
# Combining Columns: cat2_cat5
# Combining Columns: cat2_cat4
# Combining Columns: cat2_cat14
# Combining Columns: cat2_cat38
# Combining Columns: cat2_cat24
# Combining Columns: cat2_cat82
# Combining Columns: cat2_cat25
# Combining Columns: cat2_cat100
# Combining Columns: cat2_cat101
# Combining Columns: cat2_cat114
# Combining Columns: cat72_cat81
# Combining Columns: cat72_cat11
# Combining Columns: cat72_cat1
# Combining Columns: cat72_cat13
# Combining Columns: cat72_cat9
# Combining Columns: cat72_cat3
# Combining Columns: cat72_cat16
# Combining Columns: cat72_cat90
# Combining Columns: cat72_cat23
# Combining Columns: cat72_cat36
# Combining Columns: cat72_cat73
# Combining Columns: cat72_cat103
# Combining Columns: cat72_cat40
# Combining Columns: cat72_cat28
# Combining Columns: cat72_cat111
# Combining Columns: cat72_cat6
# Combining Columns: cat72_cat76
# Combining Columns: cat72_cat50
# Combining Columns: cat72_cat5
# Combining Columns: cat72_cat4
# Combining Columns: cat72_cat14
# Combining Columns: cat72_cat38
# Combining Columns: cat72_cat24
# Combining Columns: cat72_cat82
# Combining Columns: cat72_cat25
# Combining Columns: cat72_cat100
# Combining Columns: cat72_cat101
# Combining Columns: cat72_cat114
# Combining Columns: cat81_cat11
# Combining Columns: cat81_cat1
# Combining Columns: cat81_cat13
# Combining Columns: cat81_cat9
# Combining Columns: cat81_cat3
# Combining Columns: cat81_cat16
# Combining Columns: cat81_cat90
# Combining Columns: cat81_cat23
# Combining Columns: cat81_cat36
# Combining Columns: cat81_cat73
# Combining Columns: cat81_cat103
# Combining Columns: cat81_cat40
# Combining Columns: cat81_cat28
# Combining Columns: cat81_cat111
# Combining Columns: cat81_cat6
# Combining Columns: cat81_cat76
# Combining Columns: cat81_cat50
# Combining Columns: cat81_cat5
# Combining Columns: cat81_cat4
# Combining Columns: cat81_cat14
# Combining Columns: cat81_cat38
# Combining Columns: cat81_cat24
# Combining Columns: cat81_cat82
# Combining Columns: cat81_cat25
# Combining Columns: cat81_cat100
# Combining Columns: cat81_cat101
# Combining Columns: cat81_cat114
# Combining Columns: cat11_cat1
# Combining Columns: cat11_cat13
# Combining Columns: cat11_cat9
# Combining Columns: cat11_cat3
# Combining Columns: cat11_cat16
# Combining Columns: cat11_cat90
# Combining Columns: cat11_cat23
# Combining Columns: cat11_cat36
# Combining Columns: cat11_cat73
# Combining Columns: cat11_cat103
# Combining Columns: cat11_cat40
# Combining Columns: cat11_cat28
# Combining Columns: cat11_cat111
# Combining Columns: cat11_cat6
# Combining Columns: cat11_cat76
# Combining Columns: cat11_cat50
# Combining Columns: cat11_cat5
# Combining Columns: cat11_cat4
# Combining Columns: cat11_cat14
# Combining Columns: cat11_cat38
# Combining Columns: cat11_cat24
# Combining Columns: cat11_cat82
# Combining Columns: cat11_cat25
# Combining Columns: cat11_cat100
# Combining Columns: cat11_cat101
# Combining Columns: cat11_cat114
# Combining Columns: cat1_cat13
# Combining Columns: cat1_cat9
# Combining Columns: cat1_cat3
# Combining Columns: cat1_cat16
# Combining Columns: cat1_cat90
# Combining Columns: cat1_cat23
# Combining Columns: cat1_cat36
# Combining Columns: cat1_cat73
# Combining Columns: cat1_cat103
# Combining Columns: cat1_cat40
# Combining Columns: cat1_cat28
# Combining Columns: cat1_cat111
# Combining Columns: cat1_cat6
# Combining Columns: cat1_cat76
# Combining Columns: cat1_cat50
# Combining Columns: cat1_cat5
# Combining Columns: cat1_cat4
# Combining Columns: cat1_cat14
# Combining Columns: cat1_cat38
# Combining Columns: cat1_cat24
# Combining Columns: cat1_cat82
# Combining Columns: cat1_cat25
# Combining Columns: cat1_cat100
# Combining Columns: cat1_cat101
# Combining Columns: cat1_cat114
# Combining Columns: cat13_cat9
# Combining Columns: cat13_cat3
# Combining Columns: cat13_cat16
# Combining Columns: cat13_cat90
# Combining Columns: cat13_cat23
# Combining Columns: cat13_cat36
# Combining Columns: cat13_cat73
# Combining Columns: cat13_cat103
# Combining Columns: cat13_cat40
# Combining Columns: cat13_cat28
# Combining Columns: cat13_cat111
# Combining Columns: cat13_cat6
# Combining Columns: cat13_cat76
# Combining Columns: cat13_cat50
# Combining Columns: cat13_cat5
# Combining Columns: cat13_cat4
# Combining Columns: cat13_cat14
# Combining Columns: cat13_cat38
# Combining Columns: cat13_cat24
# Combining Columns: cat13_cat82
# Combining Columns: cat13_cat25
# Combining Columns: cat13_cat100
# Combining Columns: cat13_cat101
# Combining Columns: cat13_cat114
# Combining Columns: cat9_cat3
# Combining Columns: cat9_cat16
# Combining Columns: cat9_cat90
# Combining Columns: cat9_cat23
# Combining Columns: cat9_cat36
# Combining Columns: cat9_cat73
# Combining Columns: cat9_cat103
# Combining Columns: cat9_cat40
# Combining Columns: cat9_cat28
# Combining Columns: cat9_cat111
# Combining Columns: cat9_cat6
# Combining Columns: cat9_cat76
# Combining Columns: cat9_cat50
# Combining Columns: cat9_cat5
# Combining Columns: cat9_cat4
# Combining Columns: cat9_cat14
# Combining Columns: cat9_cat38
# Combining Columns: cat9_cat24
# Combining Columns: cat9_cat82
# Combining Columns: cat9_cat25
# Combining Columns: cat9_cat100
# Combining Columns: cat9_cat101
# Combining Columns: cat9_cat114
# Combining Columns: cat3_cat16
# Combining Columns: cat3_cat90
# Combining Columns: cat3_cat23
# Combining Columns: cat3_cat36
# Combining Columns: cat3_cat73
# Combining Columns: cat3_cat103
# Combining Columns: cat3_cat40
# Combining Columns: cat3_cat28
# Combining Columns: cat3_cat111
# Combining Columns: cat3_cat6
# Combining Columns: cat3_cat76
# Combining Columns: cat3_cat50
# Combining Columns: cat3_cat5
# Combining Columns: cat3_cat4
# Combining Columns: cat3_cat14
# Combining Columns: cat3_cat38
# Combining Columns: cat3_cat24
# Combining Columns: cat3_cat82
# Combining Columns: cat3_cat25
# Combining Columns: cat3_cat100
# Combining Columns: cat3_cat101
# Combining Columns: cat3_cat114
# Combining Columns: cat16_cat90
# Combining Columns: cat16_cat23
# Combining Columns: cat16_cat36
# Combining Columns: cat16_cat73
# Combining Columns: cat16_cat103
# Combining Columns: cat16_cat40
# Combining Columns: cat16_cat28
# Combining Columns: cat16_cat111
# Combining Columns: cat16_cat6
# Combining Columns: cat16_cat76
# Combining Columns: cat16_cat50
# Combining Columns: cat16_cat5
# Combining Columns: cat16_cat4
# Combining Columns: cat16_cat14
# Combining Columns: cat16_cat38
# Combining Columns: cat16_cat24
# Combining Columns: cat16_cat82
# Combining Columns: cat16_cat25
# Combining Columns: cat16_cat100
# Combining Columns: cat16_cat101
# Combining Columns: cat16_cat114
# Combining Columns: cat90_cat23
# Combining Columns: cat90_cat36
# Combining Columns: cat90_cat73
# Combining Columns: cat90_cat103
# Combining Columns: cat90_cat40
# Combining Columns: cat90_cat28
# Combining Columns: cat90_cat111
# Combining Columns: cat90_cat6
# Combining Columns: cat90_cat76
# Combining Columns: cat90_cat50
# Combining Columns: cat90_cat5
# Combining Columns: cat90_cat4
# Combining Columns: cat90_cat14
# Combining Columns: cat90_cat38
# Combining Columns: cat90_cat24
# Combining Columns: cat90_cat82
# Combining Columns: cat90_cat25
# Combining Columns: cat90_cat100
# Combining Columns: cat90_cat101
# Combining Columns: cat90_cat114
# Combining Columns: cat23_cat36
# Combining Columns: cat23_cat73
# Combining Columns: cat23_cat103
# Combining Columns: cat23_cat40
# Combining Columns: cat23_cat28
# Combining Columns: cat23_cat111
# Combining Columns: cat23_cat6
# Combining Columns: cat23_cat76
# Combining Columns: cat23_cat50
# Combining Columns: cat23_cat5
# Combining Columns: cat23_cat4
# Combining Columns: cat23_cat14
# Combining Columns: cat23_cat38
# Combining Columns: cat23_cat24
# Combining Columns: cat23_cat82
# Combining Columns: cat23_cat25
# Combining Columns: cat23_cat100
# Combining Columns: cat23_cat101
# Combining Columns: cat23_cat114
# Combining Columns: cat36_cat73
# Combining Columns: cat36_cat103
# Combining Columns: cat36_cat40
# Combining Columns: cat36_cat28
# Combining Columns: cat36_cat111
# Combining Columns: cat36_cat6
# Combining Columns: cat36_cat76
# Combining Columns: cat36_cat50
# Combining Columns: cat36_cat5
# Combining Columns: cat36_cat4
# Combining Columns: cat36_cat14
# Combining Columns: cat36_cat38
# Combining Columns: cat36_cat24
# Combining Columns: cat36_cat82
# Combining Columns: cat36_cat25
# Combining Columns: cat36_cat100
# Combining Columns: cat36_cat101
# Combining Columns: cat36_cat114
# Combining Columns: cat73_cat103
# Combining Columns: cat73_cat40
# Combining Columns: cat73_cat28
# Combining Columns: cat73_cat111
# Combining Columns: cat73_cat6
# Combining Columns: cat73_cat76
# Combining Columns: cat73_cat50
# Combining Columns: cat73_cat5
# Combining Columns: cat73_cat4
# Combining Columns: cat73_cat14
# Combining Columns: cat73_cat38
# Combining Columns: cat73_cat24
# Combining Columns: cat73_cat82
# Combining Columns: cat73_cat25
# Combining Columns: cat73_cat100
# Combining Columns: cat73_cat101
# Combining Columns: cat73_cat114
# Combining Columns: cat103_cat40
# Combining Columns: cat103_cat28
# Combining Columns: cat103_cat111
# Combining Columns: cat103_cat6
# Combining Columns: cat103_cat76
# Combining Columns: cat103_cat50
# Combining Columns: cat103_cat5
# Combining Columns: cat103_cat4
# Combining Columns: cat103_cat14
# Combining Columns: cat103_cat38
# Combining Columns: cat103_cat24
# Combining Columns: cat103_cat82
# Combining Columns: cat103_cat25
# Combining Columns: cat103_cat100
# Combining Columns: cat103_cat101
# Combining Columns: cat103_cat114
# Combining Columns: cat40_cat28
# Combining Columns: cat40_cat111
# Combining Columns: cat40_cat6
# Combining Columns: cat40_cat76
# Combining Columns: cat40_cat50
# Combining Columns: cat40_cat5
# Combining Columns: cat40_cat4
# Combining Columns: cat40_cat14
# Combining Columns: cat40_cat38
# Combining Columns: cat40_cat24
# Combining Columns: cat40_cat82
# Combining Columns: cat40_cat25
# Combining Columns: cat40_cat100
# Combining Columns: cat40_cat101
# Combining Columns: cat40_cat114
# Combining Columns: cat28_cat111
# Combining Columns: cat28_cat6
# Combining Columns: cat28_cat76
# Combining Columns: cat28_cat50
# Combining Columns: cat28_cat5
# Combining Columns: cat28_cat4
# Combining Columns: cat28_cat14
# Combining Columns: cat28_cat38
# Combining Columns: cat28_cat24
# Combining Columns: cat28_cat82
# Combining Columns: cat28_cat25
# Combining Columns: cat28_cat100
# Combining Columns: cat28_cat101
# Combining Columns: cat28_cat114
# Combining Columns: cat111_cat6
# Combining Columns: cat111_cat76
# Combining Columns: cat111_cat50
# Combining Columns: cat111_cat5
# Combining Columns: cat111_cat4
# Combining Columns: cat111_cat14
# Combining Columns: cat111_cat38
# Combining Columns: cat111_cat24
# Combining Columns: cat111_cat82
# Combining Columns: cat111_cat25
# Combining Columns: cat111_cat100
# Combining Columns: cat111_cat101
# Combining Columns: cat111_cat114
# Combining Columns: cat6_cat76
# Combining Columns: cat6_cat50
# Combining Columns: cat6_cat5
# Combining Columns: cat6_cat4
# Combining Columns: cat6_cat14
# Combining Columns: cat6_cat38
# Combining Columns: cat6_cat24
# Combining Columns: cat6_cat82
# Combining Columns: cat6_cat25
# Combining Columns: cat6_cat100
# Combining Columns: cat6_cat101
# Combining Columns: cat6_cat114
# Combining Columns: cat76_cat50
# Combining Columns: cat76_cat5
# Combining Columns: cat76_cat4
# Combining Columns: cat76_cat14
# Combining Columns: cat76_cat38
# Combining Columns: cat76_cat24
# Combining Columns: cat76_cat82
# Combining Columns: cat76_cat25
# Combining Columns: cat76_cat100
# Combining Columns: cat76_cat101
# Combining Columns: cat76_cat114
# Combining Columns: cat50_cat5
# Combining Columns: cat50_cat4
# Combining Columns: cat50_cat14
# Combining Columns: cat50_cat38
# Combining Columns: cat50_cat24
# Combining Columns: cat50_cat82
# Combining Columns: cat50_cat25
# Combining Columns: cat50_cat100
# Combining Columns: cat50_cat101
# Combining Columns: cat50_cat114
# Combining Columns: cat5_cat4
# Combining Columns: cat5_cat14
# Combining Columns: cat5_cat38
# Combining Columns: cat5_cat24
# Combining Columns: cat5_cat82
# Combining Columns: cat5_cat25
# Combining Columns: cat5_cat100
# Combining Columns: cat5_cat101
# Combining Columns: cat5_cat114
# Combining Columns: cat4_cat14
# Combining Columns: cat4_cat38
# Combining Columns: cat4_cat24
# Combining Columns: cat4_cat82
# Combining Columns: cat4_cat25
# Combining Columns: cat4_cat100
# Combining Columns: cat4_cat101
# Combining Columns: cat4_cat114
# Combining Columns: cat14_cat38
# Combining Columns: cat14_cat24
# Combining Columns: cat14_cat82
# Combining Columns: cat14_cat25
# Combining Columns: cat14_cat100
# Combining Columns: cat14_cat101
# Combining Columns: cat14_cat114
# Combining Columns: cat38_cat24
# Combining Columns: cat38_cat82
# Combining Columns: cat38_cat25
# Combining Columns: cat38_cat100
# Combining Columns: cat38_cat101
# Combining Columns: cat38_cat114
# Combining Columns: cat24_cat82
# Combining Columns: cat24_cat25
# Combining Columns: cat24_cat100
# Combining Columns: cat24_cat101
# Combining Columns: cat24_cat114
# Combining Columns: cat82_cat25
# Combining Columns: cat82_cat100
# Combining Columns: cat82_cat101
# Combining Columns: cat82_cat114
# Combining Columns: cat25_cat100
# Combining Columns: cat25_cat101
# Combining Columns: cat25_cat114
# Combining Columns: cat100_cat101
# Combining Columns: cat100_cat114
# Combining Columns: cat101_cat114
#
# Analyzing Column: cat1
# Analyzing Column: cat2
# Analyzing Column: cat3
# Analyzing Column: cat4
# Analyzing Column: cat5
# Analyzing Column: cat6
# Analyzing Column: cat7
# Analyzing Column: cat8
# Analyzing Column: cat9
# Analyzing Column: cat10
# Analyzing Column: cat11
# Analyzing Column: cat12
# Analyzing Column: cat13
# Analyzing Column: cat14
# Analyzing Column: cat15
# Analyzing Column: cat16
# Analyzing Column: cat17
# Analyzing Column: cat18
# Analyzing Column: cat19
# Analyzing Column: cat20
# Analyzing Column: cat21
# Analyzing Column: cat22
# Analyzing Column: cat23
# Analyzing Column: cat24
# Analyzing Column: cat25
# Analyzing Column: cat26
# Analyzing Column: cat27
# Analyzing Column: cat28
# Analyzing Column: cat29
# Analyzing Column: cat30
# Analyzing Column: cat31
# Analyzing Column: cat32
# Analyzing Column: cat33
# Analyzing Column: cat34
# Analyzing Column: cat35
# Analyzing Column: cat36
# Analyzing Column: cat37
# Analyzing Column: cat38
# Analyzing Column: cat39
# Analyzing Column: cat40
# Analyzing Column: cat41
# Analyzing Column: cat42
# Analyzing Column: cat43
# Analyzing Column: cat44
# Analyzing Column: cat45
# Analyzing Column: cat46
# Analyzing Column: cat47
# Analyzing Column: cat48
# Analyzing Column: cat49
# Analyzing Column: cat50
# Analyzing Column: cat51
# Analyzing Column: cat52
# Analyzing Column: cat53
# Analyzing Column: cat54
# Analyzing Column: cat55
# Analyzing Column: cat56
# Analyzing Column: cat57
# Analyzing Column: cat58
# Analyzing Column: cat59
# Analyzing Column: cat60
# Analyzing Column: cat61
# Analyzing Column: cat62
# Analyzing Column: cat63
# Analyzing Column: cat64
# Analyzing Column: cat65
# Analyzing Column: cat66
# Analyzing Column: cat67
# Analyzing Column: cat68
# Analyzing Column: cat69
# Analyzing Column: cat70
# Analyzing Column: cat71
# Analyzing Column: cat72
# Analyzing Column: cat73
# Analyzing Column: cat74
# Analyzing Column: cat75
# Analyzing Column: cat76
# Analyzing Column: cat77
# Analyzing Column: cat78
# Analyzing Column: cat79
# Analyzing Column: cat80
# Analyzing Column: cat81
# Analyzing Column: cat82
# Analyzing Column: cat83
# Analyzing Column: cat84
# Analyzing Column: cat85
# Analyzing Column: cat86
# Analyzing Column: cat87
# Analyzing Column: cat88
# Analyzing Column: cat89
# Analyzing Column: cat90
# Analyzing Column: cat91
# Analyzing Column: cat92
# Analyzing Column: cat93
# Analyzing Column: cat94
# Analyzing Column: cat95
# Analyzing Column: cat96
# Analyzing Column: cat97
# Analyzing Column: cat98
# Analyzing Column: cat99
# Analyzing Column: cat100
# Analyzing Column: cat101
# Analyzing Column: cat102
# Analyzing Column: cat103
# Analyzing Column: cat104
# Analyzing Column: cat105
# Analyzing Column: cat106
# Analyzing Column: cat107
# Analyzing Column: cat108
# Analyzing Column: cat109
# Analyzing Column: cat110
# Analyzing Column: cat111
# Analyzing Column: cat112
# Analyzing Column: cat113
# Analyzing Column: cat114
# Analyzing Column: cat115
# Analyzing Column: cat116
#         cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  cat10   ...    \
# 0          1     2     1     2     1     1     1     1     2      1   ...
# 1          1     2     1     1     1     1     1     1     2      2   ...
# 2          1     2     1     1     2     1     1     1     2      2   ...
# 3          2     2     1     2     1     1     1     1     2      1   ...
# 4          1     2     1     2     1     1     1     1     2      2   ...
# 5          1     2     1     1     1     1     1     1     2      1   ...
# 6          1     1     1     1     2     1     1     1     1      1   ...
# 7          1     2     1     2     1     1     1     1     2      1   ...
# 8          1     2     2     2     2     1     1     1     2      2   ...
# 9          1     2     1     1     2     2     1     1     2      1   ...
# 10         1     2     1     1     1     1     1     1     2      2   ...
# 11         1     2     1     1     2     1     1     1     2      2   ...
# 12         2     1     1     1     2     1     1     1     1      1   ...
# 13         2     1     1     1     2     2     1     1     1      1   ...
# 14         1     1     1     1     2     1     1     1     1      1   ...
# 15         1     1     1     1     2     2     1     1     1      1   ...
# 16         1     2     2     1     1     1     1     1     2      2   ...
# 17         1     1     1     1     1     2     1     1     1      1   ...
# 18         1     1     2     1     1     2     1     1     1      1   ...
# 19         1     1     1     2     1     1     1     1     1      1   ...
# 20         2     2     1     2     1     1     1     1     2      1   ...
# 21         1     1     1     2     1     2     1     1     1      1   ...
# 22         2     1     1     1     2     2     1     1     1      1   ...
# 23         2     1     1     2     1     1     1     1     1      1   ...
# 24         2     1     1     1     1     1     1     1     1      1   ...
# 25         1     1     1     2     1     1     1     1     1      1   ...
# 26         1     1     1     1     1     2     1     1     1      1   ...
# 27         2     1     1     2     1     1     1     1     1      1   ...
# 28         1     2     1     2     1     2     1     1     2      1   ...
# 29         1     1     1     1     2     1     1     1     1      1   ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 313834     1     2     1     1     1     1     1     2     2      1   ...
# 313835     1     2     1     2     2     1     1     1     2      2   ...
# 313836     1     2     1     1     2     1     1     1     2      1   ...
# 313837     2     1     1     1     1     2     1     1     1      1   ...
# 313838     2     2     1     1     1     1     1     1     2      2   ...
# 313839     1     1     1     1     1     2     1     1     1      1   ...
# 313840     1     1     1     1     1     2     1     1     1      1   ...
# 313841     1     2     1     1     1     2     1     1     2      1   ...
# 313842     1     1     1     1     1     2     1     1     1      1   ...
# 313843     1     1     1     1     2     1     1     1     1      1   ...
# 313844     1     1     1     1     1     2     1     1     1      1   ...
# 313845     1     1     1     2     2     1     1     1     1      1   ...
# 313846     1     1     1     1     1     2     1     1     1      1   ...
# 313847     1     1     2     1     1     1     1     1     1      1   ...
# 313848     1     2     1     1     2     1     1     1     2      1   ...
# 313849     1     2     1     1     1     1     1     1     2      1   ...
# 313850     1     1     1     2     2     1     2     1     1      1   ...
# 313851     1     1     1     2     1     1     1     1     1      1   ...
# 313852     1     2     1     1     2     1     1     1     2      1   ...
# 313853     2     1     1     1     2     2     1     1     1      1   ...
# 313854     2     1     1     1     2     1     1     1     1      1   ...
# 313855     1     1     1     2     1     1     1     1     1      1   ...
# 313856     1     2     1     1     2     1     1     1     2      1   ...
# 313857     1     1     1     2     1     1     1     1     1      1   ...
# 313858     1     1     2     1     1     2     1     1     1      1   ...
# 313859     1     1     1     2     1     1     1     1     1      1   ...
# 313860     1     1     1     1     2     2     1     2     1      1   ...
# 313861     2     2     1     1     2     1     1     1     2      2   ...
# 313862     1     1     1     1     1     2     1     2     1      1   ...
# 313863     1     2     1     1     1     1     1     1     2      1   ...
#
#         cat107  cat108  cat109  cat110  cat111  cat112  cat113  cat114  \
# 0           10       7      73      55       3      45      19       1
# 1           11      11      61      95       1      48      65       1
# 2            6       1      28     115       1       3      32       1
# 3           11      11      61      97       3      14      31       1
# 4            7       2       8       3       3      25      65       1
# 5            6       2      61      97       1      45      31       1
# 6            6       2      61     115       1      10      32       1
# 7            9       7      61     132       7      34      25       1
# 8           13      11      61      55       3      11      50       1
# 9           10       7      73     127       1      21      19      10
# 10           6       4      61      39       1      45       8       1
# 11           6       2      61      35       1       5      50       1
# 12          11      11      61      97       1       5      31       1
# 13           7       1      28     137       1      37      11       5
# 14           8       7      61     137       1      34      12       1
# 15           8      11      61      95       1      35      65       3
# 16           6       2      61      90       1      31       1       1
# 17           7       7      73      55       1       1      19       6
# 18           6       4      61      97       1      48      10       6
# 19          11      11      61      71       5      12      65       1
# 20          11      11      61      97       3       6      31       1
# 21          12      11      61      35       3      42      25       5
# 22          11       9      61     132       1      45      31       6
# 23           6       2      61      97       9      30      65       1
# 24           6       1      61      72       1      32      32       1
# 25           6       2      61     132       5      48      37       1
# 26           7       4      61     137       1      38       8       5
# 27           6       2      61      97       5       5      65       1
# 28           9       6      61     132       7      40      31       3
# 29          10       6      28     132       1      21      14       1
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 313834      11      11      61     132       1      45      31       1
# 313835      12       3      61     127       3      14      25       1
# 313836       7       2      18     142       1      34      37       1
# 313837      11      11      83       3       1      45      63      10
# 313838       6       2      61      72       1      48      50       1
# 313839       9       6      61     132       1      42      31       5
# 313840       6       4      61      90       1       5      46       3
# 313841       7       4      61      90       1       5      40       5
# 313842       9       6      61     127       1      49      19       3
# 313843       8       2      13      93       1      10      50       1
# 313844       6       2      61      97       1      34      31      12
# 313845      10      11      28     137       5      45      12       1
# 313846      11      11      61      72       1      27      50       6
# 313847       6       4      61      88       1      45      41       1
# 313848      11      11      11     132       1       5      31       1
# 313849       6       2      61      90       1      45       9       1
# 313850       9      11      61      90       7      34      30       1
# 313851       5       4      61     137      11       9       8       1
# 313852      10      11      61      68       1       3      65       1
# 313853       7       4      61      23       1       3      33       5
# 313854       5       4      61      29       1       5       8       1
# 313855       9       6      61      72       7      14      50       1
# 313856       8       4      61     142       1      10       8       1
# 313857      10       1      11     142       5      39      32       1
# 313858       7       2      61      90       1      39      62       3
# 313859       6       4      61      90       3      35       8       1
# 313860      10      11      61     117       1      48      62      10
# 313861       8       7      61      68       1       5      65       1
# 313862      11      11      11     132       1      11      31       5
# 313863       7       2      28     142       1      32      32       1
#
#         cat115  cat116
# 0           15     314
# 1           15     120
# 2            9     193
# 3           15     114
# 4           11      89
# 5           11     114
# 6           11     114
# 7           16     327
# 8           17     239
# 9           15     337
# 10          11     201
# 11          11     219
# 12          15     114
# 13          11     107
# 14          16     354
# 15          12     123
# 16          10     114
# 17          15     317
# 18          11     225
# 19          18     218
# 20          15     114
# 21          16     185
# 22          14      77
# 23          11     120
# 24           9     232
# 25          11     220
# 26          11     201
# 27          11     114
# 28          14     219
# 29          13     215
# ...        ...     ...
# 313834      14     219
# 313835      18     309
# 313836      11     115
# 313837      16     193
# 313838      11     120
# 313839      14     219
# 313840      10     222
# 313841      10     191
# 313842      13     215
# 313843      12      96
# 313844      11     114
# 313845      15     218
# 313846      17     336
# 313847      10     219
# 313848      15     114
# 313849      11     225
# 313850      14     225
# 313851      10     318
# 313852      15     201
# 313853      12     219
# 313854      10     318
# 313855      15     219
# 313856      11     201
# 313857      13      80
# 313858      12     120
# 313859      11     201
# 313860      15     120
# 313861      16     337
# 313862      15     114
# 313863      12      96
#
# [313864 rows x 116 columns]
#
# Median Loss: 2115.5699999999997
# Mean Loss: 3037.3376856699792
#
#  Fold 1
# [0]	train-rmse:4.88379	eval-rmse:4.88471	train-mae:3216.54	eval-mae:3224.87
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 50 rounds.
# [1]	train-rmse:3.78074	eval-rmse:3.78141	train-mae:3174.87	eval-mae:3183.17
# [2]	train-rmse:3.11389	eval-rmse:3.11395	train-mae:3113.98	eval-mae:3122.17
# [3]	train-rmse:2.66192	eval-rmse:2.6621	train-mae:3040.6	eval-mae:3048.75
# [4]	train-rmse:2.33313	eval-rmse:2.33299	train-mae:2960.48	eval-mae:2968.45
# [5]	train-rmse:2.08345	eval-rmse:2.08292	train-mae:2878.01	eval-mae:2885.68
# [6]	train-rmse:1.88706	eval-rmse:1.88652	train-mae:2795.3	eval-mae:2802.72
# [7]	train-rmse:1.72822	eval-rmse:1.72746	train-mae:2714.48	eval-mae:2721.59
# [8]	train-rmse:1.59708	eval-rmse:1.59619	train-mae:2635.97	eval-mae:2642.86
# [9]	train-rmse:1.4875	eval-rmse:1.48666	train-mae:2560.73	eval-mae:2567.5
# [10]	train-rmse:1.39383	eval-rmse:1.39297	train-mae:2488.54	eval-mae:2495.05
# [11]	train-rmse:1.31375	eval-rmse:1.31291	train-mae:2420.04	eval-mae:2426.43
# [12]	train-rmse:1.24358	eval-rmse:1.24274	train-mae:2354.42	eval-mae:2360.71
# [13]	train-rmse:1.18215	eval-rmse:1.1814	train-mae:2292.01	eval-mae:2298.34
# [14]	train-rmse:1.12786	eval-rmse:1.12713	train-mae:2233.19	eval-mae:2239.42
# [15]	train-rmse:1.07978	eval-rmse:1.07912	train-mae:2177.5	eval-mae:2183.82
# [16]	train-rmse:1.03659	eval-rmse:1.03598	train-mae:2124.75	eval-mae:2131.14
# [17]	train-rmse:0.997475	eval-rmse:0.997051	train-mae:2074.59	eval-mae:2081.14
# [18]	train-rmse:0.962217	eval-rmse:0.961876	train-mae:2027.45	eval-mae:2033.95
# [19]	train-rmse:0.930147	eval-rmse:0.929857	train-mae:1982.79	eval-mae:1989.22
# [20]	train-rmse:0.900582	eval-rmse:0.900447	train-mae:1940.25	eval-mae:1946.76
# [21]	train-rmse:0.873256	eval-rmse:0.873291	train-mae:1899.66	eval-mae:1906.28
# [22]	train-rmse:0.84839	eval-rmse:0.848588	train-mae:1861.51	eval-mae:1868.38
# [23]	train-rmse:0.82536	eval-rmse:0.825693	train-mae:1825.1	eval-mae:1832.25
# [24]	train-rmse:0.803903	eval-rmse:0.80444	train-mae:1790.44	eval-mae:1797.85
# [25]	train-rmse:0.783983	eval-rmse:0.784728	train-mae:1757.57	eval-mae:1765.35
# [26]	train-rmse:0.765562	eval-rmse:0.766544	train-mae:1726.55	eval-mae:1734.8
# [27]	train-rmse:0.748429	eval-rmse:0.749556	train-mae:1697.1	eval-mae:1705.69
# [28]	train-rmse:0.73237	eval-rmse:0.733698	train-mae:1668.91	eval-mae:1677.99
# [29]	train-rmse:0.717363	eval-rmse:0.718894	train-mae:1642.17	eval-mae:1651.68
# [30]	train-rmse:0.703298	eval-rmse:0.705063	train-mae:1616.76	eval-mae:1626.69
# [31]	train-rmse:0.690179	eval-rmse:0.69215	train-mae:1592.7	eval-mae:1603.06
# [32]	train-rmse:0.677837	eval-rmse:0.68001	train-mae:1569.77	eval-mae:1580.63
# [33]	train-rmse:0.66619	eval-rmse:0.668574	train-mae:1547.98	eval-mae:1559.39
# [34]	train-rmse:0.655305	eval-rmse:0.657953	train-mae:1527.33	eval-mae:1539.36
# [35]	train-rmse:0.645048	eval-rmse:0.647952	train-mae:1507.68	eval-mae:1520.23
# [36]	train-rmse:0.63551	eval-rmse:0.638601	train-mae:1489.17	eval-mae:1502.09
# [37]	train-rmse:0.626473	eval-rmse:0.629804	train-mae:1471.42	eval-mae:1484.75
# [38]	train-rmse:0.618016	eval-rmse:0.621559	train-mae:1454.64	eval-mae:1468.45
# [39]	train-rmse:0.610011	eval-rmse:0.613746	train-mae:1438.76	eval-mae:1452.91
# [40]	train-rmse:0.6025	eval-rmse:0.606429	train-mae:1423.62	eval-mae:1438.2
# [41]	train-rmse:0.595306	eval-rmse:0.599478	train-mae:1409.01	eval-mae:1424.16
# [42]	train-rmse:0.588603	eval-rmse:0.593005	train-mae:1395.26	eval-mae:1410.89
# [43]	train-rmse:0.582271	eval-rmse:0.586938	train-mae:1382.17	eval-mae:1398.38
# [44]	train-rmse:0.57622	eval-rmse:0.581145	train-mae:1369.58	eval-mae:1386.34
# [45]	train-rmse:0.570526	eval-rmse:0.575683	train-mae:1357.59	eval-mae:1374.81
# [46]	train-rmse:0.565201	eval-rmse:0.570594	train-mae:1346.34	eval-mae:1364.09
# [47]	train-rmse:0.560219	eval-rmse:0.565851	train-mae:1335.72	eval-mae:1353.98
# [48]	train-rmse:0.555423	eval-rmse:0.561292	train-mae:1325.39	eval-mae:1344.23
# [49]	train-rmse:0.550898	eval-rmse:0.556948	train-mae:1315.61	eval-mae:1334.81
# [50]	train-rmse:0.546641	eval-rmse:0.55289	train-mae:1306.35	eval-mae:1326.06
# [51]	train-rmse:0.54268	eval-rmse:0.549099	train-mae:1297.68	eval-mae:1317.9
# [52]	train-rmse:0.538882	eval-rmse:0.545519	train-mae:1289.31	eval-mae:1310.13
# [53]	train-rmse:0.535283	eval-rmse:0.542146	train-mae:1281.38	eval-mae:1302.78
# [54]	train-rmse:0.531886	eval-rmse:0.538981	train-mae:1273.84	eval-mae:1295.86
# [55]	train-rmse:0.528719	eval-rmse:0.535941	train-mae:1266.69	eval-mae:1289.12
# [56]	train-rmse:0.525705	eval-rmse:0.533124	train-mae:1259.84	eval-mae:1282.77
# [57]	train-rmse:0.522827	eval-rmse:0.530391	train-mae:1253.27	eval-mae:1276.74
# [58]	train-rmse:0.520058	eval-rmse:0.527856	train-mae:1246.97	eval-mae:1271.07
# [59]	train-rmse:0.517506	eval-rmse:0.525498	train-mae:1241.13	eval-mae:1265.75
# [60]	train-rmse:0.515015	eval-rmse:0.523212	train-mae:1235.36	eval-mae:1260.52
# [61]	train-rmse:0.512727	eval-rmse:0.521114	train-mae:1230.06	eval-mae:1255.81
# [62]	train-rmse:0.510585	eval-rmse:0.519152	train-mae:1225.02	eval-mae:1251.3
# [63]	train-rmse:0.508531	eval-rmse:0.517274	train-mae:1220.15	eval-mae:1246.94
# [64]	train-rmse:0.506527	eval-rmse:0.515453	train-mae:1215.41	eval-mae:1242.76
# [65]	train-rmse:0.504695	eval-rmse:0.513756	train-mae:1210.99	eval-mae:1238.73
# [66]	train-rmse:0.502915	eval-rmse:0.512143	train-mae:1206.7	eval-mae:1234.87
# [67]	train-rmse:0.501211	eval-rmse:0.510637	train-mae:1202.53	eval-mae:1231.21
# [68]	train-rmse:0.49958	eval-rmse:0.509177	train-mae:1198.52	eval-mae:1227.66
# [69]	train-rmse:0.498016	eval-rmse:0.507832	train-mae:1194.63	eval-mae:1224.35
# [70]	train-rmse:0.496616	eval-rmse:0.506593	train-mae:1191.24	eval-mae:1221.37
# [71]	train-rmse:0.495245	eval-rmse:0.505355	train-mae:1187.88	eval-mae:1218.39
# [72]	train-rmse:0.493948	eval-rmse:0.504203	train-mae:1184.72	eval-mae:1215.7
# [73]	train-rmse:0.492724	eval-rmse:0.503133	train-mae:1181.62	eval-mae:1213.03
# [74]	train-rmse:0.491582	eval-rmse:0.502139	train-mae:1178.74	eval-mae:1210.6
# [75]	train-rmse:0.490494	eval-rmse:0.501214	train-mae:1175.92	eval-mae:1208.31
# [76]	train-rmse:0.489477	eval-rmse:0.500314	train-mae:1173.29	eval-mae:1206.08
# [77]	train-rmse:0.488536	eval-rmse:0.499481	train-mae:1170.91	eval-mae:1204.01
# [78]	train-rmse:0.487624	eval-rmse:0.498679	train-mae:1168.59	eval-mae:1202.03
# [79]	train-rmse:0.48668	eval-rmse:0.497852	train-mae:1166.25	eval-mae:1200.06
# [80]	train-rmse:0.485804	eval-rmse:0.497116	train-mae:1163.98	eval-mae:1198.2
# [81]	train-rmse:0.484999	eval-rmse:0.496464	train-mae:1161.89	eval-mae:1196.53
# [82]	train-rmse:0.484289	eval-rmse:0.495848	train-mae:1160.08	eval-mae:1194.97
# [83]	train-rmse:0.483513	eval-rmse:0.495218	train-mae:1158	eval-mae:1193.39
# [84]	train-rmse:0.482866	eval-rmse:0.49468	train-mae:1156.32	eval-mae:1192
# [85]	train-rmse:0.482145	eval-rmse:0.494153	train-mae:1154.38	eval-mae:1190.65
# [86]	train-rmse:0.48148	eval-rmse:0.493627	train-mae:1152.51	eval-mae:1189.22
# [87]	train-rmse:0.480961	eval-rmse:0.493157	train-mae:1151.12	eval-mae:1188.04
# [88]	train-rmse:0.48034	eval-rmse:0.492716	train-mae:1149.44	eval-mae:1186.87
# [89]	train-rmse:0.479751	eval-rmse:0.49228	train-mae:1147.83	eval-mae:1185.68
# [90]	train-rmse:0.479224	eval-rmse:0.491853	train-mae:1146.37	eval-mae:1184.53
# [91]	train-rmse:0.478747	eval-rmse:0.491473	train-mae:1145.02	eval-mae:1183.5
# [92]	train-rmse:0.478319	eval-rmse:0.491087	train-mae:1143.84	eval-mae:1182.47
# [93]	train-rmse:0.477821	eval-rmse:0.49068	train-mae:1142.46	eval-mae:1181.37
# [94]	train-rmse:0.477403	eval-rmse:0.490338	train-mae:1141.34	eval-mae:1180.45
# [95]	train-rmse:0.476966	eval-rmse:0.48999	train-mae:1140.09	eval-mae:1179.44
# [96]	train-rmse:0.476505	eval-rmse:0.489669	train-mae:1138.87	eval-mae:1178.61
# [97]	train-rmse:0.476138	eval-rmse:0.489386	train-mae:1137.86	eval-mae:1177.83
# [98]	train-rmse:0.475716	eval-rmse:0.489099	train-mae:1136.68	eval-mae:1177.06
# [99]	train-rmse:0.475406	eval-rmse:0.488849	train-mae:1135.79	eval-mae:1176.29
# [100]	train-rmse:0.474961	eval-rmse:0.488526	train-mae:1134.48	eval-mae:1175.33
# [101]	train-rmse:0.47462	eval-rmse:0.48825	train-mae:1133.51	eval-mae:1174.59
# [102]	train-rmse:0.474286	eval-rmse:0.488024	train-mae:1132.53	eval-mae:1173.9
# [103]	train-rmse:0.473926	eval-rmse:0.487754	train-mae:1131.49	eval-mae:1173.1
# [104]	train-rmse:0.473656	eval-rmse:0.487555	train-mae:1130.67	eval-mae:1172.46
# [105]	train-rmse:0.473388	eval-rmse:0.487363	train-mae:1129.9	eval-mae:1171.93
# [106]	train-rmse:0.473076	eval-rmse:0.487158	train-mae:1129.03	eval-mae:1171.36
# [107]	train-rmse:0.472788	eval-rmse:0.486988	train-mae:1128.22	eval-mae:1170.82
# [108]	train-rmse:0.472553	eval-rmse:0.48684	train-mae:1127.54	eval-mae:1170.4
# [109]	train-rmse:0.472265	eval-rmse:0.486678	train-mae:1126.62	eval-mae:1169.83
# [110]	train-rmse:0.472006	eval-rmse:0.486538	train-mae:1125.82	eval-mae:1169.38
# [111]	train-rmse:0.471753	eval-rmse:0.486406	train-mae:1125.07	eval-mae:1169.06
# [112]	train-rmse:0.471587	eval-rmse:0.486271	train-mae:1124.6	eval-mae:1168.7
# [113]	train-rmse:0.471356	eval-rmse:0.486117	train-mae:1123.91	eval-mae:1168.25
# [114]	train-rmse:0.47114	eval-rmse:0.485961	train-mae:1123.27	eval-mae:1167.74
# [115]	train-rmse:0.470949	eval-rmse:0.485826	train-mae:1122.7	eval-mae:1167.3
# [116]	train-rmse:0.470796	eval-rmse:0.485692	train-mae:1122.22	eval-mae:1166.88
# [117]	train-rmse:0.470613	eval-rmse:0.48555	train-mae:1121.66	eval-mae:1166.5
# [118]	train-rmse:0.470425	eval-rmse:0.4854	train-mae:1121.17	eval-mae:1166.11
# [119]	train-rmse:0.470287	eval-rmse:0.485319	train-mae:1120.71	eval-mae:1165.79
# [120]	train-rmse:0.470044	eval-rmse:0.48521	train-mae:1119.95	eval-mae:1165.31
# [121]	train-rmse:0.469861	eval-rmse:0.48511	train-mae:1119.43	eval-mae:1165.04
# [122]	train-rmse:0.469712	eval-rmse:0.48501	train-mae:1118.97	eval-mae:1164.79
# [123]	train-rmse:0.469569	eval-rmse:0.484913	train-mae:1118.52	eval-mae:1164.51
# [124]	train-rmse:0.469424	eval-rmse:0.484787	train-mae:1118.1	eval-mae:1164.17
# [125]	train-rmse:0.469226	eval-rmse:0.484657	train-mae:1117.54	eval-mae:1163.84
# [126]	train-rmse:0.468992	eval-rmse:0.48453	train-mae:1116.83	eval-mae:1163.42
# [127]	train-rmse:0.468768	eval-rmse:0.484413	train-mae:1116.13	eval-mae:1163.02
# [128]	train-rmse:0.468654	eval-rmse:0.484358	train-mae:1115.76	eval-mae:1162.79
# [129]	train-rmse:0.468552	eval-rmse:0.484291	train-mae:1115.42	eval-mae:1162.53
# [130]	train-rmse:0.468335	eval-rmse:0.484175	train-mae:1114.74	eval-mae:1162.16
# [131]	train-rmse:0.468216	eval-rmse:0.484102	train-mae:1114.37	eval-mae:1161.93
# [132]	train-rmse:0.468044	eval-rmse:0.484002	train-mae:1113.81	eval-mae:1161.53
# [133]	train-rmse:0.467958	eval-rmse:0.483937	train-mae:1113.51	eval-mae:1161.32
# [134]	train-rmse:0.467848	eval-rmse:0.483889	train-mae:1113.14	eval-mae:1161.16
# [135]	train-rmse:0.467673	eval-rmse:0.483832	train-mae:1112.57	eval-mae:1160.89
# [136]	train-rmse:0.467557	eval-rmse:0.483747	train-mae:1112.26	eval-mae:1160.66
# [137]	train-rmse:0.467377	eval-rmse:0.483643	train-mae:1111.69	eval-mae:1160.32
# [138]	train-rmse:0.467223	eval-rmse:0.483543	train-mae:1111.19	eval-mae:1160
# [139]	train-rmse:0.467042	eval-rmse:0.483487	train-mae:1110.65	eval-mae:1159.77
# [140]	train-rmse:0.466964	eval-rmse:0.483435	train-mae:1110.4	eval-mae:1159.57
# [141]	train-rmse:0.466826	eval-rmse:0.483359	train-mae:1109.98	eval-mae:1159.33
# [142]	train-rmse:0.466696	eval-rmse:0.483313	train-mae:1109.56	eval-mae:1159.15
# [143]	train-rmse:0.466557	eval-rmse:0.483267	train-mae:1109.13	eval-mae:1158.98
# [144]	train-rmse:0.466424	eval-rmse:0.483164	train-mae:1108.74	eval-mae:1158.76
# [145]	train-rmse:0.466334	eval-rmse:0.483107	train-mae:1108.46	eval-mae:1158.6
# [146]	train-rmse:0.466259	eval-rmse:0.483051	train-mae:1108.19	eval-mae:1158.44
# [147]	train-rmse:0.466104	eval-rmse:0.483013	train-mae:1107.72	eval-mae:1158.29
# [148]	train-rmse:0.465981	eval-rmse:0.482969	train-mae:1107.34	eval-mae:1158.08
# [149]	train-rmse:0.465858	eval-rmse:0.482919	train-mae:1106.9	eval-mae:1157.89
# ...
# [683]	train-rmse:0.436813	eval-rmse:0.470203	train-mae:1017.43	eval-mae:1122.41
# [684]	train-rmse:0.436779	eval-rmse:0.470198	train-mae:1017.31	eval-mae:1122.43
# [685]	train-rmse:0.436713	eval-rmse:0.470196	train-mae:1017.13	eval-mae:1122.39
# [686]	train-rmse:0.436668	eval-rmse:0.470204	train-mae:1016.94	eval-mae:1122.38
# [687]	train-rmse:0.436655	eval-rmse:0.470208	train-mae:1016.9	eval-mae:1122.4
# [688]	train-rmse:0.436632	eval-rmse:0.470199	train-mae:1016.8	eval-mae:1122.39
# [689]	train-rmse:0.43662	eval-rmse:0.470205	train-mae:1016.75	eval-mae:1122.41
# [690]	train-rmse:0.436598	eval-rmse:0.470206	train-mae:1016.68	eval-mae:1122.42
# [691]	train-rmse:0.436574	eval-rmse:0.470201	train-mae:1016.62	eval-mae:1122.39
# [692]	train-rmse:0.436543	eval-rmse:0.47019	train-mae:1016.52	eval-mae:1122.37
# [693]	train-rmse:0.436477	eval-rmse:0.470194	train-mae:1016.32	eval-mae:1122.41
# [694]	train-rmse:0.436433	eval-rmse:0.470189	train-mae:1016.19	eval-mae:1122.41
# [695]	train-rmse:0.436399	eval-rmse:0.470188	train-mae:1016.11	eval-mae:1122.41
# [696]	train-rmse:0.436348	eval-rmse:0.470179	train-mae:1015.98	eval-mae:1122.36
# [697]	train-rmse:0.436305	eval-rmse:0.470178	train-mae:1015.86	eval-mae:1122.33
# [698]	train-rmse:0.436287	eval-rmse:0.470174	train-mae:1015.81	eval-mae:1122.32
# [699]	train-rmse:0.436239	eval-rmse:0.470179	train-mae:1015.7	eval-mae:1122.31
# [700]	train-rmse:0.436182	eval-rmse:0.470176	train-mae:1015.52	eval-mae:1122.33
# [701]	train-rmse:0.436164	eval-rmse:0.470167	train-mae:1015.45	eval-mae:1122.3
# [702]	train-rmse:0.436159	eval-rmse:0.470163	train-mae:1015.43	eval-mae:1122.27
# [703]	train-rmse:0.436057	eval-rmse:0.470158	train-mae:1015.16	eval-mae:1122.24
# [704]	train-rmse:0.436002	eval-rmse:0.470154	train-mae:1015	eval-mae:1122.22
# [705]	train-rmse:0.435932	eval-rmse:0.470158	train-mae:1014.82	eval-mae:1122.25
# [706]	train-rmse:0.435901	eval-rmse:0.470165	train-mae:1014.73	eval-mae:1122.26
# [707]	train-rmse:0.435832	eval-rmse:0.47017	train-mae:1014.56	eval-mae:1122.28
# [708]	train-rmse:0.435796	eval-rmse:0.470171	train-mae:1014.47	eval-mae:1122.3
# [709]	train-rmse:0.435772	eval-rmse:0.47016	train-mae:1014.39	eval-mae:1122.28
# [710]	train-rmse:0.435753	eval-rmse:0.470149	train-mae:1014.33	eval-mae:1122.26
# [711]	train-rmse:0.435724	eval-rmse:0.470144	train-mae:1014.25	eval-mae:1122.24
# [712]	train-rmse:0.435691	eval-rmse:0.470132	train-mae:1014.15	eval-mae:1122.21
# [713]	train-rmse:0.435634	eval-rmse:0.470136	train-mae:1014	eval-mae:1122.24
# [714]	train-rmse:0.435581	eval-rmse:0.47013	train-mae:1013.86	eval-mae:1122.23
# [715]	train-rmse:0.435566	eval-rmse:0.470127	train-mae:1013.81	eval-mae:1122.23
# [716]	train-rmse:0.435503	eval-rmse:0.470129	train-mae:1013.63	eval-mae:1122.25
# [717]	train-rmse:0.435446	eval-rmse:0.470123	train-mae:1013.46	eval-mae:1122.2
# [718]	train-rmse:0.435428	eval-rmse:0.470123	train-mae:1013.39	eval-mae:1122.2
# [719]	train-rmse:0.435381	eval-rmse:0.470124	train-mae:1013.25	eval-mae:1122.24
# [720]	train-rmse:0.435359	eval-rmse:0.470125	train-mae:1013.19	eval-mae:1122.26
# [721]	train-rmse:0.435276	eval-rmse:0.470119	train-mae:1012.92	eval-mae:1122.23
# [722]	train-rmse:0.435239	eval-rmse:0.470117	train-mae:1012.77	eval-mae:1122.24
# [723]	train-rmse:0.435208	eval-rmse:0.47012	train-mae:1012.68	eval-mae:1122.22
# [724]	train-rmse:0.43517	eval-rmse:0.470113	train-mae:1012.55	eval-mae:1122.21
# [725]	train-rmse:0.435125	eval-rmse:0.470101	train-mae:1012.4	eval-mae:1122.22
# [726]	train-rmse:0.435066	eval-rmse:0.47009	train-mae:1012.26	eval-mae:1122.22
# [727]	train-rmse:0.435037	eval-rmse:0.470088	train-mae:1012.16	eval-mae:1122.22
# [728]	train-rmse:0.434999	eval-rmse:0.470089	train-mae:1012.04	eval-mae:1122.23
# [729]	train-rmse:0.434965	eval-rmse:0.470079	train-mae:1011.93	eval-mae:1122.21
# [730]	train-rmse:0.434912	eval-rmse:0.470052	train-mae:1011.77	eval-mae:1122.14
# [731]	train-rmse:0.434865	eval-rmse:0.470061	train-mae:1011.63	eval-mae:1122.14
# [732]	train-rmse:0.434811	eval-rmse:0.470056	train-mae:1011.49	eval-mae:1122.12
# [733]	train-rmse:0.434747	eval-rmse:0.470051	train-mae:1011.29	eval-mae:1122.1
# [734]	train-rmse:0.434717	eval-rmse:0.470038	train-mae:1011.19	eval-mae:1122.04
# [735]	train-rmse:0.434674	eval-rmse:0.470036	train-mae:1011.07	eval-mae:1122.06
# [736]	train-rmse:0.434653	eval-rmse:0.470032	train-mae:1011	eval-mae:1122.05
# [737]	train-rmse:0.434608	eval-rmse:0.470038	train-mae:1010.85	eval-mae:1122.07
# [738]	train-rmse:0.434576	eval-rmse:0.470041	train-mae:1010.75	eval-mae:1122.07
# [739]	train-rmse:0.434523	eval-rmse:0.470042	train-mae:1010.55	eval-mae:1122.05
# [740]	train-rmse:0.434499	eval-rmse:0.470038	train-mae:1010.46	eval-mae:1122.05
# [741]	train-rmse:0.434464	eval-rmse:0.470036	train-mae:1010.35	eval-mae:1122.05
# [742]	train-rmse:0.434433	eval-rmse:0.470037	train-mae:1010.27	eval-mae:1122.07
# [743]	train-rmse:0.434414	eval-rmse:0.47004	train-mae:1010.22	eval-mae:1122.08
# [744]	train-rmse:0.434388	eval-rmse:0.470048	train-mae:1010.14	eval-mae:1122.09
# [745]	train-rmse:0.434349	eval-rmse:0.470045	train-mae:1010.02	eval-mae:1122.02
# [746]	train-rmse:0.434331	eval-rmse:0.470048	train-mae:1009.97	eval-mae:1122.05
# [747]	train-rmse:0.4343	eval-rmse:0.470054	train-mae:1009.87	eval-mae:1122.05
# [748]	train-rmse:0.43426	eval-rmse:0.470054	train-mae:1009.75	eval-mae:1122.08
# [749]	train-rmse:0.434249	eval-rmse:0.470043	train-mae:1009.7	eval-mae:1122.07
# [750]	train-rmse:0.434205	eval-rmse:0.470042	train-mae:1009.58	eval-mae:1122.11
# [751]	train-rmse:0.434143	eval-rmse:0.470037	train-mae:1009.4	eval-mae:1122.04
# [752]	train-rmse:0.434076	eval-rmse:0.470036	train-mae:1009.19	eval-mae:1122.05
# [753]	train-rmse:0.434029	eval-rmse:0.47003	train-mae:1009.04	eval-mae:1122.05
# [754]	train-rmse:0.433956	eval-rmse:0.470028	train-mae:1008.82	eval-mae:1122.04
# [755]	train-rmse:0.433939	eval-rmse:0.470023	train-mae:1008.78	eval-mae:1122.02
# [756]	train-rmse:0.433883	eval-rmse:0.470031	train-mae:1008.6	eval-mae:1122.07
# [757]	train-rmse:0.43384	eval-rmse:0.470036	train-mae:1008.46	eval-mae:1122.11
# [758]	train-rmse:0.433818	eval-rmse:0.470036	train-mae:1008.38	eval-mae:1122.12
# [759]	train-rmse:0.433795	eval-rmse:0.47003	train-mae:1008.29	eval-mae:1122.1
# [760]	train-rmse:0.43377	eval-rmse:0.470033	train-mae:1008.21	eval-mae:1122.15
# [761]	train-rmse:0.43376	eval-rmse:0.470029	train-mae:1008.17	eval-mae:1122.14
# [762]	train-rmse:0.433722	eval-rmse:0.470029	train-mae:1008.08	eval-mae:1122.12
# [763]	train-rmse:0.433679	eval-rmse:0.470028	train-mae:1007.95	eval-mae:1122.1
# [764]	train-rmse:0.433638	eval-rmse:0.470026	train-mae:1007.85	eval-mae:1122.11
# [765]	train-rmse:0.433609	eval-rmse:0.470022	train-mae:1007.75	eval-mae:1122.08
# [766]	train-rmse:0.433557	eval-rmse:0.470023	train-mae:1007.56	eval-mae:1122.04
# [767]	train-rmse:0.433531	eval-rmse:0.470027	train-mae:1007.48	eval-mae:1122.08
# [768]	train-rmse:0.433489	eval-rmse:0.470034	train-mae:1007.34	eval-mae:1122.11
# [769]	train-rmse:0.433459	eval-rmse:0.470037	train-mae:1007.24	eval-mae:1122.14
# [770]	train-rmse:0.433401	eval-rmse:0.470035	train-mae:1007.06	eval-mae:1122.15
# [771]	train-rmse:0.43336	eval-rmse:0.470027	train-mae:1006.92	eval-mae:1122.13
# [772]	train-rmse:0.433297	eval-rmse:0.470034	train-mae:1006.72	eval-mae:1122.15
# [773]	train-rmse:0.43326	eval-rmse:0.470035	train-mae:1006.57	eval-mae:1122.11
# [774]	train-rmse:0.433231	eval-rmse:0.470036	train-mae:1006.5	eval-mae:1122.12
# [775]	train-rmse:0.433214	eval-rmse:0.470038	train-mae:1006.46	eval-mae:1122.11
# [776]	train-rmse:0.433188	eval-rmse:0.470026	train-mae:1006.38	eval-mae:1122.1
# [777]	train-rmse:0.433159	eval-rmse:0.470021	train-mae:1006.29	eval-mae:1122.08
# [778]	train-rmse:0.433093	eval-rmse:0.470022	train-mae:1006.12	eval-mae:1122.12
# [779]	train-rmse:0.433036	eval-rmse:0.470014	train-mae:1005.96	eval-mae:1122.12
# [780]	train-rmse:0.432975	eval-rmse:0.469997	train-mae:1005.8	eval-mae:1122.07
# [781]	train-rmse:0.432957	eval-rmse:0.46999	train-mae:1005.73	eval-mae:1122.03
# [782]	train-rmse:0.43293	eval-rmse:0.46999	train-mae:1005.64	eval-mae:1122.03
# [783]	train-rmse:0.432882	eval-rmse:0.469987	train-mae:1005.51	eval-mae:1122.04
# [784]	train-rmse:0.432877	eval-rmse:0.469989	train-mae:1005.5	eval-mae:1122.05
# [785]	train-rmse:0.432843	eval-rmse:0.470002	train-mae:1005.42	eval-mae:1122.07
# [786]	train-rmse:0.432831	eval-rmse:0.470006	train-mae:1005.38	eval-mae:1122.08
# [787]	train-rmse:0.432807	eval-rmse:0.470007	train-mae:1005.3	eval-mae:1122.06
# [788]	train-rmse:0.432788	eval-rmse:0.470004	train-mae:1005.22	eval-mae:1122.04
# [789]	train-rmse:0.432748	eval-rmse:0.469986	train-mae:1005.1	eval-mae:1122
# [790]	train-rmse:0.432725	eval-rmse:0.469983	train-mae:1005.02	eval-mae:1121.99
# [791]	train-rmse:0.432682	eval-rmse:0.469985	train-mae:1004.86	eval-mae:1121.98
# [792]	train-rmse:0.432653	eval-rmse:0.469982	train-mae:1004.79	eval-mae:1121.98
# [793]	train-rmse:0.432604	eval-rmse:0.469988	train-mae:1004.62	eval-mae:1121.97
# [794]	train-rmse:0.432564	eval-rmse:0.469968	train-mae:1004.49	eval-mae:1121.95
# [795]	train-rmse:0.43254	eval-rmse:0.469961	train-mae:1004.43	eval-mae:1121.96
# [796]	train-rmse:0.432481	eval-rmse:0.469952	train-mae:1004.28	eval-mae:1121.94
# [797]	train-rmse:0.432446	eval-rmse:0.46995	train-mae:1004.17	eval-mae:1121.94
# [798]	train-rmse:0.432395	eval-rmse:0.469943	train-mae:1004.02	eval-mae:1121.95
# [799]	train-rmse:0.432364	eval-rmse:0.469941	train-mae:1003.9	eval-mae:1121.9
# [800]	train-rmse:0.43233	eval-rmse:0.469936	train-mae:1003.81	eval-mae:1121.92
# [801]	train-rmse:0.432276	eval-rmse:0.469938	train-mae:1003.65	eval-mae:1121.93
# [802]	train-rmse:0.432231	eval-rmse:0.469931	train-mae:1003.54	eval-mae:1121.91
# [803]	train-rmse:0.432169	eval-rmse:0.46992	train-mae:1003.36	eval-mae:1121.88
# [804]	train-rmse:0.432136	eval-rmse:0.469923	train-mae:1003.22	eval-mae:1121.9
# [805]	train-rmse:0.432103	eval-rmse:0.469921	train-mae:1003.1	eval-mae:1121.91
# [806]	train-rmse:0.432069	eval-rmse:0.469909	train-mae:1002.99	eval-mae:1121.84
# [807]	train-rmse:0.432003	eval-rmse:0.469909	train-mae:1002.79	eval-mae:1121.82
# [808]	train-rmse:0.431967	eval-rmse:0.469901	train-mae:1002.66	eval-mae:1121.78
# [809]	train-rmse:0.431927	eval-rmse:0.469895	train-mae:1002.55	eval-mae:1121.73
# [810]	train-rmse:0.431889	eval-rmse:0.469894	train-mae:1002.43	eval-mae:1121.72
# [811]	train-rmse:0.431844	eval-rmse:0.469897	train-mae:1002.32	eval-mae:1121.75
# [812]	train-rmse:0.431755	eval-rmse:0.46991	train-mae:1002.05	eval-mae:1121.74
# [813]	train-rmse:0.431715	eval-rmse:0.469916	train-mae:1001.94	eval-mae:1121.76
# [814]	train-rmse:0.431705	eval-rmse:0.469919	train-mae:1001.92	eval-mae:1121.77
# [815]	train-rmse:0.431662	eval-rmse:0.469913	train-mae:1001.78	eval-mae:1121.73
# [816]	train-rmse:0.431622	eval-rmse:0.469919	train-mae:1001.66	eval-mae:1121.72
# [817]	train-rmse:0.431608	eval-rmse:0.469917	train-mae:1001.6	eval-mae:1121.7
# [818]	train-rmse:0.431586	eval-rmse:0.46992	train-mae:1001.5	eval-mae:1121.7
# [819]	train-rmse:0.431554	eval-rmse:0.469913	train-mae:1001.41	eval-mae:1121.69
# [820]	train-rmse:0.431518	eval-rmse:0.469914	train-mae:1001.29	eval-mae:1121.71
# [821]	train-rmse:0.431467	eval-rmse:0.469908	train-mae:1001.08	eval-mae:1121.66
# [822]	train-rmse:0.43145	eval-rmse:0.469912	train-mae:1001.01	eval-mae:1121.65
# [823]	train-rmse:0.431435	eval-rmse:0.469911	train-mae:1000.96	eval-mae:1121.65
# [824]	train-rmse:0.431401	eval-rmse:0.469919	train-mae:1000.88	eval-mae:1121.68
# [825]	train-rmse:0.431362	eval-rmse:0.469905	train-mae:1000.8	eval-mae:1121.66
# [826]	train-rmse:0.43132	eval-rmse:0.46991	train-mae:1000.65	eval-mae:1121.67
# [827]	train-rmse:0.431286	eval-rmse:0.469917	train-mae:1000.52	eval-mae:1121.67
# [828]	train-rmse:0.43125	eval-rmse:0.469916	train-mae:1000.41	eval-mae:1121.62
# [829]	train-rmse:0.431216	eval-rmse:0.469923	train-mae:1000.33	eval-mae:1121.64
# [830]	train-rmse:0.431139	eval-rmse:0.469911	train-mae:1000.08	eval-mae:1121.65
# [831]	train-rmse:0.431111	eval-rmse:0.469916	train-mae:999.962	eval-mae:1121.68
# [832]	train-rmse:0.431036	eval-rmse:0.469907	train-mae:999.755	eval-mae:1121.66
# [833]	train-rmse:0.430988	eval-rmse:0.469895	train-mae:999.602	eval-mae:1121.64
# [834]	train-rmse:0.430948	eval-rmse:0.469891	train-mae:999.494	eval-mae:1121.66
# [835]	train-rmse:0.430936	eval-rmse:0.469903	train-mae:999.442	eval-mae:1121.7
# [836]	train-rmse:0.430901	eval-rmse:0.469899	train-mae:999.341	eval-mae:1121.7
# [837]	train-rmse:0.430869	eval-rmse:0.469895	train-mae:999.212	eval-mae:1121.7
# [838]	train-rmse:0.430825	eval-rmse:0.469882	train-mae:999.083	eval-mae:1121.71
# [839]	train-rmse:0.430815	eval-rmse:0.469884	train-mae:999.052	eval-mae:1121.73
# [840]	train-rmse:0.430787	eval-rmse:0.469896	train-mae:998.974	eval-mae:1121.74
# [841]	train-rmse:0.430758	eval-rmse:0.469888	train-mae:998.884	eval-mae:1121.72
# [842]	train-rmse:0.430723	eval-rmse:0.469886	train-mae:998.773	eval-mae:1121.72
# [843]	train-rmse:0.430703	eval-rmse:0.469899	train-mae:998.715	eval-mae:1121.75
# [844]	train-rmse:0.430638	eval-rmse:0.469891	train-mae:998.532	eval-mae:1121.72
# [845]	train-rmse:0.430608	eval-rmse:0.469892	train-mae:998.425	eval-mae:1121.75
# [846]	train-rmse:0.430573	eval-rmse:0.469897	train-mae:998.34	eval-mae:1121.75
# [847]	train-rmse:0.430516	eval-rmse:0.469898	train-mae:998.182	eval-mae:1121.78
# [848]	train-rmse:0.430475	eval-rmse:0.46988	train-mae:998.066	eval-mae:1121.77
# [849]	train-rmse:0.430433	eval-rmse:0.469877	train-mae:997.93	eval-mae:1121.79
# [850]	train-rmse:0.430386	eval-rmse:0.469875	train-mae:997.793	eval-mae:1121.81
# [851]	train-rmse:0.430348	eval-rmse:0.469879	train-mae:997.679	eval-mae:1121.8
# [852]	train-rmse:0.430305	eval-rmse:0.469876	train-mae:997.531	eval-mae:1121.78
# [853]	train-rmse:0.430262	eval-rmse:0.469871	train-mae:997.409	eval-mae:1121.79
# [854]	train-rmse:0.430242	eval-rmse:0.469876	train-mae:997.357	eval-mae:1121.8
# [855]	train-rmse:0.430175	eval-rmse:0.46988	train-mae:997.166	eval-mae:1121.81
# [856]	train-rmse:0.43014	eval-rmse:0.469881	train-mae:997.067	eval-mae:1121.8
# [857]	train-rmse:0.430088	eval-rmse:0.469876	train-mae:996.93	eval-mae:1121.78
# [858]	train-rmse:0.430068	eval-rmse:0.469877	train-mae:996.859	eval-mae:1121.79
# [859]	train-rmse:0.430017	eval-rmse:0.469876	train-mae:996.733	eval-mae:1121.82
# [860]	train-rmse:0.429987	eval-rmse:0.469877	train-mae:996.638	eval-mae:1121.86
# [861]	train-rmse:0.429937	eval-rmse:0.469876	train-mae:996.494	eval-mae:1121.88
# [862]	train-rmse:0.429863	eval-rmse:0.469874	train-mae:996.288	eval-mae:1121.9
# [863]	train-rmse:0.429839	eval-rmse:0.469875	train-mae:996.173	eval-mae:1121.88
# [864]	train-rmse:0.429804	eval-rmse:0.46988	train-mae:996.059	eval-mae:1121.93
# [865]	train-rmse:0.429756	eval-rmse:0.469884	train-mae:995.899	eval-mae:1121.96
# [866]	train-rmse:0.429748	eval-rmse:0.469889	train-mae:995.864	eval-mae:1121.97
# [867]	train-rmse:0.429715	eval-rmse:0.469893	train-mae:995.776	eval-mae:1121.98
# [868]	train-rmse:0.429697	eval-rmse:0.469886	train-mae:995.716	eval-mae:1121.95
# [869]	train-rmse:0.429678	eval-rmse:0.469888	train-mae:995.648	eval-mae:1121.94
# [870]	train-rmse:0.429644	eval-rmse:0.469894	train-mae:995.549	eval-mae:1121.94
# [871]	train-rmse:0.429596	eval-rmse:0.469883	train-mae:995.376	eval-mae:1121.95
# [872]	train-rmse:0.429553	eval-rmse:0.46988	train-mae:995.237	eval-mae:1121.94
# [873]	train-rmse:0.429526	eval-rmse:0.469876	train-mae:995.119	eval-mae:1121.95
# [874]	train-rmse:0.429509	eval-rmse:0.469876	train-mae:995.054	eval-mae:1121.95
# [875]	train-rmse:0.429475	eval-rmse:0.469868	train-mae:994.958	eval-mae:1121.94
# [876]	train-rmse:0.429451	eval-rmse:0.469866	train-mae:994.88	eval-mae:1121.92
# [877]	train-rmse:0.429408	eval-rmse:0.469869	train-mae:994.749	eval-mae:1121.96
# [878]	train-rmse:0.429387	eval-rmse:0.46987	train-mae:994.702	eval-mae:1121.97
# Stopping. Best iteration:
# [828]	train-rmse:0.43125	eval-rmse:0.469916	train-mae:1000.41	eval-mae:1121.62
#
# eval-MAE: 1121.621874
# Average eval-MAE: 1130.954403
# Writing results
# 10-fold average prediction:
# Writing submission: C:\Users\Egor\Desktop\kaggle\allstate\04\submission_5fold-average-xgb_fairobj_1130.954403_2016-12-10-14-00.csv

# %%
clf.best_ntree_limit
# Out:
# 829

# %%
xgb_rounds
# Out:
# [827, 925, 847, 896, 792, 718, 782, 822, 708, 828]
